# %%
import pandas as pd

# %%
data = {"Name":["Hohn", "lisa", "maz"],
       "Age": [23,45,34],
       "Salary": [30000,34909,7663]}
df = pd.DataFrame(data)
print(df)

# %%
data = pd.read_csv("D:/Downloads/Feb gst.CSV")
print(data)
# Out:
#           Date      Time Time zone                   Name  \
# 0   01/02/2024  10:59:14       IST                    NaN
# 1   01/02/2024  10:59:14       IST                    NaN
# 2   01/02/2024  10:59:14       IST                    NaN
# 3   02/02/2024  00:54:26       IST           Steven Mixer
# 4   03/02/2024  04:08:28       IST                    NaN
# ..         ...       ...       ...                    ...
# 57  28/02/2024  05:45:47       IST             Jeanie Lau
# 58  28/02/2024  12:36:27       IST  Alessandra Cantarella
# 59  29/02/2024  05:43:51       IST                    NaN
# 60  29/02/2024  05:43:51       IST                    NaN
# 61  29/02/2024  05:43:51       IST                    NaN
#
#                            Type     Status Currency      Gross   Fee  \
# 0     User Initiated Withdrawal  Completed      INR  -4,302.52  0.00
# 1   General Currency Conversion  Completed      USD     -53.75  0.00
# ...

# %%
# Exploring Data in pandas
data = pd.read_csv("D:/Downloads/Feb gst.CSV")
print(data)
print(data.head(10))

# %%
data = pd.read_csv("D:/Downloads/Feb gst.CSV")
print(data)
print(data.head(10))
print(data.tail(10)) #using Tail
# Out:
#           Date      Time Time zone                   Name  \
# 0   01/02/2024  10:59:14       IST                    NaN
# 1   01/02/2024  10:59:14       IST                    NaN
# 2   01/02/2024  10:59:14       IST                    NaN
# 3   02/02/2024  00:54:26       IST           Steven Mixer
# 4   03/02/2024  04:08:28       IST                    NaN
# ..         ...       ...       ...                    ...
# 57  28/02/2024  05:45:47       IST             Jeanie Lau
# 58  28/02/2024  12:36:27       IST  Alessandra Cantarella
# 59  29/02/2024  05:43:51       IST                    NaN
# 60  29/02/2024  05:43:51       IST                    NaN
# 61  29/02/2024  05:43:51       IST                    NaN
#
#                            Type     Status Currency      Gross   Fee  \
# 0     User Initiated Withdrawal  Completed      INR  -4,302.52  0.00
# 1   General Currency Conversion  Completed      USD     -53.75  0.00
# ...

# %%
#How to get information and data type of data
print(data.info)

# %%
data.describe() #Give overall discribtion
# Out:
#              Fee       Item ID  Postage and Packaging Amount  \
# count  62.000000  1.600000e+01                          16.0
# mean   -0.651774  1.192833e+09                           0.0
# std     1.102194  2.178434e+08                           0.0
# min    -3.110000  9.095981e+08                           0.0
# 25%    -1.762500  1.063699e+09                           0.0
# 50%     0.000000  1.143371e+09                           0.0
# 75%     0.000000  1.200359e+09                           0.0
# max     0.000000  1.604803e+09                           0.0
#
#        Insurance Amount        VAT  Option 1 Name  Option 1 Value  \
# count               0.0  16.000000            0.0             0.0
# mean                NaN   4.294375            NaN             NaN
# std                 NaN   2.552134            NaN             NaN
# min                 NaN   1.580000            NaN             NaN
# 25%                 NaN   2.565000            NaN             NaN
# ...

# %%
#how to see null value
print (data.isnull())
# Out:
#      Date   Time  Time zone   Name   Type  Status  Currency  Gross    Fee  \
# 0   False  False      False   True  False   False     False  False  False
# 1   False  False      False   True  False   False     False  False  False
# 2   False  False      False   True  False   False     False  False  False
# 3   False  False      False  False  False   False     False  False  False
# 4   False  False      False   True  False   False     False  False  False
# ..    ...    ...        ...    ...    ...     ...       ...    ...    ...
# 57  False  False      False  False  False   False     False  False  False
# 58  False  False      False  False  False   False     False  False  False
# 59  False  False      False   True  False   False     False  False  False
# 60  False  False      False   True  False   False     False  False  False
# 61  False  False      False   True  False   False     False  False  False
#
#       Net  ...  Address Line 2/District/Neighbourhood  Town/City  County  \
# ...

# %%
print (data.isnull().sum()) #show null value column wise
