# %%
import pandas as pd

# %%
data = pd.read_csv("D:/Downloads/Nov Gst.CSV")
print(data)
# Out:
#                                                  Date      Time  \
# 0                                           11/2/2023  19:51:21
# 1                                           11/2/2023  20:19:56
# 2                                           11/3/2023  03:23:34
# 3                                           11/3/2023  06:06:00
# 4                                           11/4/2023  03:08:44
# 5                                          11/14/2023  22:13:10
# 6                                          11/15/2023  05:00:47
# 7                                          11/19/2023  20:57:22
# 8                                          11/20/2023  05:08:30
# 9                                          11/23/2023  20:29:00
# 10                                         11/24/2023  04:15:04
# 11                                         11/25/2023  04:00:04
# 12                                         11/25/2023  05:02:08
# 13                                         11/26/2023  04:12:17
# ...

# %%
data.loc [(data["Net"] ==33.33 ), "getsbonus"] = "no"

# %%
datas = {"month":["January","February","March","April","May"]}
a = pd.DataFrame(datas)
print(a)

def extract(value):
    return value[0:3]

a["Short_months"]= a["month"].map(extract)
print(a)
# Out:
#       month
# 0   January
# 1  February
# 2     March
# 3     April
# 4       May
#       month Short_months
# 0   January          Jan
# 1  February          Feb
# 2     March          Mar
# 3     April          Apr
# 4       May          May
