# %%
import pandas as pd

# %%
data = pd.read_csv("D:/Downloads/March gst.CSV")
print(data)
# Out:
#           Date      Time Time zone                       Name  \
# 0   04/03/2024  10:46:34       IST               jayden haigh
# 1   05/03/2024  04:18:53       IST                        NaN
# 2   05/03/2024  04:18:53       IST                        NaN
# 3   05/03/2024  04:18:53       IST                        NaN
# 4   06/03/2024  00:25:24       IST                Naomi Vance
# 5   07/03/2024  04:28:21       IST                        NaN
# 6   07/03/2024  04:28:21       IST                        NaN
# 7   07/03/2024  04:28:21       IST                        NaN
# 8   07/03/2024  07:38:33       IST                      Tietq
# 9   08/03/2024  03:32:57       IST               Gregory Hack
# 10  08/03/2024  04:56:55       IST                        NaN
# 11  08/03/2024  04:56:55       IST                        NaN
# 12  08/03/2024  04:56:55       IST                        NaN
# 13  09/03/2024  04:33:17       IST           sophie laplanche
# ...

# %%
print(data.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# 57    False
# 58    False
# dtype: bool

# %%
print(data["Time"].duplicated().sum()) #find duplicate value from column
# Out:
# 29

# %%
print(data.drop_duplicates("Time")) #remove duplicate value from given column
# Out:
#           Date      Time Time zone                       Name  \
# 0   04/03/2024  10:46:34       IST               jayden haigh
# 1   05/03/2024  04:18:53       IST                        NaN
# 4   06/03/2024  00:25:24       IST                Naomi Vance
# 5   07/03/2024  04:28:21       IST                        NaN
# 8   07/03/2024  07:38:33       IST                      Tietq
# 9   08/03/2024  03:32:57       IST               Gregory Hack
# 10  08/03/2024  04:56:55       IST                        NaN
# 13  09/03/2024  04:33:17       IST           sophie laplanche
# 14  09/03/2024  05:06:40       IST                        NaN
# 17  09/03/2024  16:39:01       IST            Merlin Yasimova
# 18  10/03/2024  04:44:32       IST                        NaN
# 21  10/03/2024  22:12:55       IST              Scott Buckner
# 22  11/03/2024  04:00:49       IST                        NaN
# 25  11/03/2024  04:24:20       IST              Anne Yorgason
# ...
